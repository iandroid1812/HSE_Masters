# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
from darts import TimeSeries
from helper_funcs.preprocessing import timeseries_init
from helper_funcs.data import cleaned_market
import matplotlib.pyplot as plt
import ta
import pandas_ta
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler()
# scaler = StandardScaler()

EXP_MA = 15

# %% [markdown]
# # Data sentiment

# %%
df_sentiment = pd.read_pickle("Datasets/results/preprocessing/sentiment_finetuned.pkl")
tickers_df = pd.read_csv("Datasets/kaggle/Company_Tweet.csv")

# %% [markdown]
# df_sentiment contains 1 or 0 as positive/negative sentiment for tweet obtained using this pretrianed model: https://huggingface.co/zhayunduo/roberta-base-stocktwits-finetuned

# %%
df_sentiment.head()
# Out:
#              tweet_id           post_date  \
# 0  550441509175443456 2015-01-01 00:00:57
# 1  550441672312512512 2015-01-01 00:01:36
# 2  550441732014223360 2015-01-01 00:01:50
# 3  550442977802207232 2015-01-01 00:06:47
# 4  550444969924653056 2015-01-01 00:14:42
#
#                                                 body  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...
# 1  Insanity of today weirdo massive selling. $aap...
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4  $AAPL Apple goes global with 'Start Something ...
#
#                                         preprocessed  interactions  \
# 0          lx madeon check it out! learn #howtotrade             1
# 1  insanity of today weirdo massive selling bid u...             0
# 2                      s&p #stocks performance more@             0
# 3       volkswagen pushes record recall tally higher             1
# 4  apple goes global with 'start something new' a...             1
#
#    sentiment_score
# 0                0
# 1                0
# 2                1
# 3                0
# 4                1

# %% [markdown]
# tickers_df maps tweet id to the company the tweet is about

# %%
tickers_df.head()
# Out:
#              tweet_id ticker_symbol
# 0  550803612197457920          AAPL
# 1  550803610825928706          AAPL
# 2  550803225113157632          AAPL
# 3  550802957370159104          AAPL
# 4  550802855129382912          AAPL

# %%
df_sentiment = df_sentiment.merge(tickers_df, on='tweet_id', how='inner')
df_sentiment = df_sentiment[['post_date', 'sentiment_score', 'ticker_symbol']]
df_sentiment
# Out:
#                   post_date  sentiment_score ticker_symbol
# 0       2015-01-01 00:00:57                0          AAPL
# 1       2015-01-01 00:01:36                0          AAPL
# 2       2015-01-01 00:01:50                1          AMZN
# 3       2015-01-01 00:06:47                0          TSLA
# 4       2015-01-01 00:14:42                1          AAPL
# ...                     ...              ...           ...
# 2777220 2019-12-31 23:51:06                1          AAPL
# 2777221 2019-12-31 23:53:03                1          AAPL
# 2777222 2019-12-31 23:53:21                0          TSLA
# 2777223 2019-12-31 23:54:03                0          TSLA
# 2777224 2019-12-31 23:55:53                1          AAPL
#
# [2777225 rows x 3 columns]

# %% [markdown]
# # Data price

# %%
timeseries = timeseries_init(
    time_col='Date',
    static_cols=[],
    value_cols=[
        'Adj Close',
        'Close',
        'High',
        'Low',
        'Open',
        'Volume'],
    freq='B',
    fill_missing=True,
    group_col='Ticker',
    type='MULTI'
    )
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
market = pd.DataFrame([])
for i in range(6):
    df = timeseries[i].pd_dataframe().reset_index()
    df['Ticker'] = timeseries[i].static_covariates_values()[0][0]
    df['Volatility'] = ta.volatility.AverageTrueRange(
        high=df.High, low=df.Low, close=df.Close, window=EXP_MA
    ).average_true_range()
    market = pd.concat([market, df], axis=0)

# %%
market
# Out:
# component       Date  Adj Close      Close       High        Low       Open  \
# 0         2015-01-02  24.603207  27.332500  27.860001  26.837500  27.847500
# 1         2015-01-05  23.910095  26.562500  27.162500  26.352501  27.072500
# 2         2015-01-06  23.912346  26.565001  26.857500  26.157499  26.635000
# 3         2015-01-07  24.247652  26.937500  27.049999  26.674999  26.799999
# 4         2015-01-08  25.179298  27.972500  28.037500  27.174999  27.307501
# ...              ...        ...        ...        ...        ...        ...
# 1298      2019-12-25  28.350000  28.350000  28.364668  27.512667  27.890667
# 1299      2019-12-26  28.729334  28.729334  28.898666  28.423332  28.527332
# 1300      2019-12-27  28.691999  28.691999  29.020666  28.407333  29.000000
# 1301      2019-12-30  27.646667  27.646667  28.600000  27.284000  28.586000
# 1302      2019-12-31  27.888666  27.888666  28.086000  26.805332  27.000000
#
# component       Volume  holidays Ticker  Volatility
# 0          212818400.0       0.0   AAPL    0.000000
# 1          257142000.0       0.0   AAPL    0.000000
# 2          263188400.0       0.0   AAPL    0.000000
# 3          160423600.0       0.0   AAPL    0.000000
# 4          237458000.0       0.0   AAPL    0.000000
# ...                ...       ...    ...         ...
# 1298       120820500.0       1.0   TSLA    0.773631
# 1299       159508500.0       0.0   TSLA    0.758633
# 1300       149185500.0       0.0   TSLA    0.748947
# 1301       188796000.0       0.0   TSLA    0.792883
# 1302       154285500.0       0.0   TSLA    0.825402
#
# [7818 rows x 10 columns]

# %% [markdown]
# # Processing sentiment

# %% [markdown]
# Using groupby to count negative and positive sentiment values for each day and each company

# %%
df_sentiment.loc[:, 'post_date'] = df_sentiment.post_date.apply(lambda x: x.to_pydatetime().date())
df_sentiment = df_sentiment.groupby(['ticker_symbol', 'post_date']).value_counts().unstack(fill_value=0)

# %% [markdown]
# ### Calculating sentiment score and it's moving average

# %%
sentiment_dict = dict()
tickers = tickers_df.ticker_symbol.value_counts().index.to_list()

# fraction of negative tweets in all tweets
def frac_by_all(negative, positive):
    if negative == 0:
        return 0
    return negative / (negative + positive)

def frac(negative, positive):
    if negative == 0:
        return 0
    return negative / positive

for ticker in tickers:
    # first we add missing dates and fill thew with 0
    company = df_sentiment.xs(ticker).reindex(pd.date_range('2015-01-01', '2019-12-31'), fill_value=0)

    # then resample to business days and add up dropped past values up to the date that is not dropped
    company = company.resample(rule="B", origin='end').sum().rename(columns = {0:'Negative', 1:'Positive'})

    # taking fractions of negative tweeets to calculate the final score 
    company['sentiment_score_1'] = company.apply(lambda row: frac_by_all(row['Negative'], row['Positive']), axis=1)
    company['sentiment_score_2'] = company.apply(lambda row: frac(row['Negative'], row['Positive']), axis=1)

    # visualize different approaches
    company.sentiment_score_1[100:200].plot(label='raw')
    company.sentiment_score_1.ewm(span=EXP_MA).mean()[100:200].plot(label='ewm')
    pandas_ta.ema(company.sentiment_score_1, length=EXP_MA)[100:200].plot(label='ema')
    company.sentiment_score_1.rolling(EXP_MA).mean()[100:200].plot(label='rolling')
    plt.title(ticker)
    plt.legend()
    plt.show()

    # calculating moving average
    company['sentiment_score_1'] = company.sentiment_score_1.ewm(span=EXP_MA).mean()
    company['sentiment_score_2'] = company.sentiment_score_2.ewm(span=EXP_MA).mean()

    company['ticker'] = ticker
    sentiment_dict[ticker] = company

# %%
data = pd.DataFrame([])
for i in range(6):
    df = timeseries[i].pd_dataframe().reset_index()
    df['Ticker'] = timeseries[i].static_covariates_values()[0][0]
    data = pd.concat([data, df], axis=0)

# %% [markdown]
# # Comparison
#
# During the comparison you can observe high correlation of Volatility for the stock price and Sentiment score that is nearly 60 percent in all cases except microsoft.
#
# First we compare raw values, then MinMax scaled for better visualization
#
# **MOVING AVERAGE = 15** (3 business weeks NYSE works 5 days a week)
#
# **sentiment_score_1 = negative / (negative + positive)**  <---- better correlation values
#
#
# **sentiment_score_2 = negative / positive**

# %%
def comparison(ticker):
    close = market[market.Ticker == ticker].set_index('Date').Close
    volume = market[market.Ticker == ticker].set_index('Date').Volume.ewm(span=EXP_MA).mean()
    sent_1 = sentiment_dict[ticker].sentiment_score_1
    sent_2 = sentiment_dict[ticker].sentiment_score_2
    atr = market[market.Ticker == ticker].set_index('Date').Volatility
    df  = pd.concat([close, volume, sent_1, sent_2, atr], axis=1).dropna()
    return df

# %% [markdown]
# ## Apple

# %%
df = comparison('AAPL')
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.corr()
# Out:
#                       Close    Volume  sentiment_score_1  sentiment_score_2  \
# Close              1.000000 -0.512560           0.199858           0.181233
# Volume            -0.512560  1.000000           0.200997           0.207038
# sentiment_score_1  0.199858  0.200997           1.000000           0.994345
# sentiment_score_2  0.181233  0.207038           0.994345           1.000000
# Volatility         0.620024  0.060741           0.654292           0.655276
#
#                    Volatility
# Close                0.620024
# Volume               0.060741
# sentiment_score_1    0.654292
# sentiment_score_2    0.655276
# Volatility           1.000000

# %%
df.Close[1000:].plot(label='Price')
((1 - (df.sentiment_score_1[1000:])) * 70).plot(label='sentiment_score_1')
((1 - (df.sentiment_score_2[1000:])) * 90).plot(label='sentiment_score_2')
plt.legend();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][1100:].plot();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][100:400].plot();

# %%
df_scaled.plot.scatter(x='Volatility', y='sentiment_score_1', c='b');
# Out:
# /home/andrei/miniconda3/envs/hse/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Microsoft

# %%
df = comparison('MSFT')
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.corr()
# Out:
#                       Close    Volume  sentiment_score_1  sentiment_score_2  \
# Close              1.000000 -0.359609           0.082361           0.079044
# Volume            -0.359609  1.000000           0.278408           0.258983
# sentiment_score_1  0.082361  0.278408           1.000000           0.994504
# sentiment_score_2  0.079044  0.258983           0.994504           1.000000
# Volatility         0.727098  0.211797           0.290556           0.279178
#
#                    Volatility
# Close                0.727098
# Volume               0.211797
# sentiment_score_1    0.290556
# sentiment_score_2    0.279178
# Volatility           1.000000

# %%
df.Close[1000:].plot(label='Price')
((1 - (df.sentiment_score_1[1000:])) * 150).plot(label='sentiment_score_1')
((1 - (df.sentiment_score_2[1000:])) * 170).plot(label='sentiment_score_2')
plt.legend();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][1100:].plot();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][100:400].plot();

# %%
df_scaled.plot.scatter(x='Volatility', y='sentiment_score_1', c='b');
# Out:
# /home/andrei/miniconda3/envs/hse/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Google

# %%
df = comparison('GOOGL')
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.corr()
# Out:
#                       Close    Volume  sentiment_score_1  sentiment_score_2  \
# Close              1.000000 -0.364192           0.439746           0.421236
# Volume            -0.364192  1.000000           0.051247           0.061710
# sentiment_score_1  0.439746  0.051247           1.000000           0.993673
# sentiment_score_2  0.421236  0.061710           0.993673           1.000000
# Volatility         0.602052  0.289945           0.574481           0.587299
#
#                    Volatility
# Close                0.602052
# Volume               0.289945
# sentiment_score_1    0.574481
# sentiment_score_2    0.587299
# Volatility           1.000000

# %%
df.Close[1000:].plot(label='Price')
((1 - (df.sentiment_score_1[1000:])) * 80).plot(label='sentiment_score_1')
((1 - (df.sentiment_score_2[1000:])) * 100).plot(label='sentiment_score_2')
plt.legend();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][1100:].plot();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][100:400].plot();

# %%
df_scaled.plot.scatter(x='Volatility', y='sentiment_score_1', c='b');
# Out:
# /home/andrei/miniconda3/envs/hse/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Tesla

# %%
df = comparison('TSLA')
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.corr()
# Out:
#                       Close    Volume  sentiment_score_1  sentiment_score_2  \
# Close              1.000000  0.366896           0.170106           0.143341
# Volume             0.366896  1.000000           0.673954           0.672992
# sentiment_score_1  0.170106  0.673954           1.000000           0.992123
# sentiment_score_2  0.143341  0.672992           0.992123           1.000000
# Volatility         0.572819  0.689891           0.557221           0.562235
#
#                    Volatility
# Close                0.572819
# Volume               0.689891
# sentiment_score_1    0.557221
# sentiment_score_2    0.562235
# Volatility           1.000000

# %%
df.Close[1000:].plot(label='Price')
((1 - (df.sentiment_score_1[1000:])) * 40).plot(label='sentiment_score_1')
((1 - (df.sentiment_score_2[1000:])) * 120).plot(label='sentiment_score_2')
plt.legend();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][1100:].plot();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][100:400].plot();

# %%
df_scaled.plot.scatter(x='Volatility', y='sentiment_score_1', c='b');
# Out:
# /home/andrei/miniconda3/envs/hse/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Amazon

# %%
df = comparison('AMZN')
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df.corr()
# Out:
#                       Close    Volume  sentiment_score_1  sentiment_score_2  \
# Close              1.000000  0.211263           0.404960           0.388139
# Volume             0.211263  1.000000           0.475974           0.493355
# sentiment_score_1  0.404960  0.475974           1.000000           0.990657
# sentiment_score_2  0.388139  0.493355           0.990657           1.000000
# Volatility         0.723124  0.723589           0.571517           0.588080
#
#                    Volatility
# Close                0.723124
# Volume               0.723589
# sentiment_score_1    0.571517
# sentiment_score_2    0.588080
# Volatility           1.000000

# %%
df.Close[1000:].plot(label='Price')
((1 - (df.sentiment_score_1[1000:])) * 130).plot(label='sentiment_score_1')
((1 - (df.sentiment_score_2[1000:])) * 160).plot(label='sentiment_score_2')
plt.legend();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][1100:].plot();

# %%
df_scaled[['sentiment_score_1', 'Volume', 'Volatility']][100:400].plot();

# %%
df_scaled.plot.scatter(x='Volatility', y='sentiment_score_1', c='b');
# Out:
# /home/andrei/miniconda3/envs/hse/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
